# %%
f= open("abc.txt", "r")
print("file name " , f.name)
print("open or close", f.closed)
print("mode" , f.mode)
print(f)
f.close()
print("open or close", f.closed)

# %%
with open("abc.txt", "r") as file : 
    content = file.read
    print(content)

# %%
with open("demo.txt", "w") as f :
    f.write("Python is fun!\n")
    f.write("File handling is important")
