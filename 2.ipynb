# %%
# wap to find the square of a number
a = int(input("Enter the number : "))
print(a*a)
# Out:
# 25

# %%
# WAP to take two number as input and print their sum 
a = int(input("Enter the number 1 : "))
b = int(input("Enter the number 2 : "))
print(a+b)

# %%
#wap to swap two variable 
a = int(input("Enter the number 1 : "))
b = int(input("Enter the number 2 : "))
temp  =a 
a=b
b=temp
print(a)
print(b)
# Out:
# 4
# 3

# %%
#wap check even odd 
a = int(input("Enter the number  : "))
if a%2==0 :
    print("even")
else :
    print("odd")
# Out:
# odd

# %%
list1 = ["apple", "banana", "cherry ", "orange", "kiwi"]
# list1.clear()
for x in list1:
    print(x)

print(len(list1))
# uppercase
newlist = [x.upper() for x in list1 ]
print(newlist)
# lowercase
lowerlist = [x.lower() for x in newlist ]
print(lowerlist)

# first letter in capitial
caplist = [x.capitalize() for x in lowerlist ]
print(caplist)

# element present in list or not
if "apple" in list1 :
    print("yes apple is present")
else :
    print("no apple is not present")

#  reverse the  string
list1.reverse()
print(list1)
# Out:
#   Cell In[4], line 28
#     list1.reverse()=True
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?
